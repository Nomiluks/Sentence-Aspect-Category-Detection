# %%
import gensim.models
from gensim.models.word2vec import Word2Vec
from gensim.models import word2vec


model = Word2Vec.load('400dm_by_5lac_yelp.model')

# %%
word1 = "shake"
word2 = "drinks"
model.most_similar(word1),"  -----------------------------  ",model.most_similar(word2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# ([('milkshake', 0.6257019639015198),
#   ('shakes', 0.5246059894561768),
#   ('loganberry', 0.5183275938034058),
#   ('oreo', 0.495998352766037),
#   ('nutella', 0.4868525266647339),
#   ('krumble', 0.47131651639938354),
#   ('peppermint', 0.46873319149017334),
#   ('mcflurry', 0.461473286151886),
#   ('frap', 0.4589877426624298),
#   ('oreos', 0.45650869607925415)],
#  '  -----------------------------  ',
#  [('drink', 0.6787455081939697),
#   ('cocktails', 0.5642061829566956),
#   ('beverages', 0.5136315822601318),
#   ('waters', 0.49310773611068726),
#   ('nonalcoholic', 0.47577911615371704),
#   ('martinis', 0.45447632670402527),
#   ('booze', 0.45278871059417725),
# ...

# %% [markdown]
# # Loading word vector of a word

# %%
word = 'drink'
model[word]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([ 0.0501392 ,  0.17120312, -0.00750922, -0.10947094, -0.17382088,
#        -0.15257828,  0.06851821, -0.09797297,  0.04974462, -0.13591075,
#         0.12669502,  0.07252932,  0.01730921,  0.1186353 ,  0.15329391,
#        -0.14262828, -0.10980622,  0.09852242, -0.19204457,  0.02405884,
#         0.0010717 , -0.07662559, -0.05379715,  0.07797407, -0.260571  ,
#        -0.00864809, -0.10293052,  0.03792249,  0.05128529,  0.05123705,
#         0.18137681, -0.0130973 , -0.07715157, -0.11345132,  0.00677575,
#        -0.13653724, -0.07224418,  0.12605608,  0.00608464, -0.00736821,
#         0.15296693, -0.12252796, -0.00984449, -0.03653895, -0.17682101,
#         0.00451145,  0.06539214,  0.07729238,  0.19520926,  0.08411794,
# ...
